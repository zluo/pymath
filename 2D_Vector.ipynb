# %%
from util_code import *
# Out:
# loading util code ...

# %%
x = np.arange(1,11)
y= 2*x + 5

plt.plot(x, y)
plt.show()

# %%
p1 = np.array((-1, 2))
p2 = np.array((3,4))
o = np.array((0,0))
draw_arrow(plt, o, p1,'blue')
draw_arrow(plt, o, p2,'green')
draw_arrow(plt, p1, p2)
draw_vector(plt, o, p2 - p1, 'black')
show(plt)

# %%
dino = dino_vectors()
xs, ys = zip(*dino)
plt.grid()
plt.scatter(xs, ys)
plt.plot(xs, ys)

# %%
dino = dino_vectors()
xs, ys = zip(*dino)

dino1 = dino + (-1.5, -2.5)
xs1,ys1 = zip(*dino1)

plt.grid()
plt.scatter(xs, ys)
plt.plot(xs, ys, color="grey")
plt.plot(xs1, ys1, color = "blue")
dino_1 = dino + (-1.5, -2.5)

# %%
dino = dino_vectors()
for i in range(10):
    for j in range(10):
        # this is called broadcasting
        d1 = dino + (i*10,j*10)
        plt.plot(*zip(*d1))
plt.show()

# %%
x = np.arange(21) -10
y = x**2
plt.grid()
plt.scatter(x,y)
plt.plot(x,y)
plt.show()
